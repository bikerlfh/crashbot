# %%
import numpy as np

# Lista de multiplicadores
multiplicadores = [

24.00,
2.61,
1.12,
1.80,
2.60,
3.55,
2.01,
1.15,
3.26,
36.39,
1.16,
6.82,
1.39,
10.47,
2.14,
1.94,
16.33,
4.38,
2.98,
1.00,
2.85,
2.05,
1.85,]
#5.15]

# Rango de interés
x = 2
x1 = 3

# Filtrar multiplicadores en el rango [x, x1]
multiplicadores_filtrados = [m for m in multiplicadores if x <= m <= x1]
print(f"datos:{multiplicadores_filtrados}")

# Calcular estadísticas
if multiplicadores_filtrados:
    media = np.mean(multiplicadores_filtrados)
    mediana = np.median(multiplicadores_filtrados)
    desviacion_estandar = np.std(multiplicadores_filtrados)

    print("Estadísticas de los multiplicadores en el rango [{}, {}]:".format(x, x1))
    print("Media: {:.2f}".format(media))
    print("Mediana: {:.2f}".format(mediana))
    print("Desviación estándar: {:.2f}".format(desviacion_estandar))
else:
    print("No hay multiplicadores en el rango [{}, {}].".format(x, x1))
# Out:
# datos:[2.61, 2.6, 2.01, 2.14, 2.98, 2.85, 2.05]
# Estadísticas de los multiplicadores en el rango [2, 3]:
# Media: 2.46
# Mediana: 2.60
# Desviación estándar: 0.37

# %%
numeros = [1.26,
2.04,
1.70,
5.96,
1.02,
1.38,
1.15,
1.80,
1.00,
2.35,
3.29,
3.24,
6.63,
1.21,
1.13,
4.27,
1.64,
48.10,
1.55,
2.40,
2.57,
1.17,
3.12,
2.16,
1.84,
2.62,
1.50,
24.55,
2.31,
5.72,
3.40,
1.52,
3.67,
1.35,
1.00,
1.67,
2.37,
11.18,
1.38,
24.00,
2.61,
1.12,
1.80,
2.60,
3.55,
2.01,
1.15,
3.26,
36.39,
1.16,
6.82,
1.39,
10.47,
2.14,
1.94,
16.33,
4.38,
2.98,
1.00,
2.85,
2.05,
1.85,
2.33,
4.72,
3.60,
2.74,
1.04,
1.24,
21.34,
6.23,
2.18,
5.16,
2.37,
2.05,
6.19,
1.53,
1.10,
35.29,
2.73,
7.14,
3.18,
1.25,
3.84,
1.39,
1.24,
2.97,
2.78,
1.24,
4.05,
1.25,
1.21,
5.33,
1.49,
6.38,
12.82,
1.69,
1.00,
3.51,
2.69,
1.00,
7.93,
1.60,
1.76,
5.17,
1.43,
2.62,
2.68,
1.44,
7.96,
6.14,
1.47,
1.45,
1.17,
4.26,
1.23,
2.03,
3.40,
1.24,
1.83,
1.88,
1.42,
3.59,
27.57,
1.30,
1.21,
2.34,
1.05,
1.86,
1.75,
6.78,
8.36,
1.74,
2.04,
1.32,
1.14,
2.21,
1.21,
2.55,
1.02,
1.00,
4.33,
2.80,
2.74,
1.85,
1.53,
1.19,
1.23,
3.88,
5.69,
1.93,
1.12,
13.29,
2.82,
2.36,
1.32,
2.42,
1.02,
1.07,
1.55,
1.06,
1.59,
5.15]
valores = [3, 5, 10, 20, 30]

def contar_posiciones(numeros, valor):
    contador = 0
    posiciones = 0

    for num in numeros:
        posiciones += 1
        if num >= valor:
            contador += 1

    if contador > 0:
        return posiciones / contador
    
    return None

for valor in valores:
    resultado = contar_posiciones(numeros, valor)
    if resultado is not None:
        print("Cada {:.2f} posiciones hay un número mayor o igual a {}.".format(resultado, valor))
    else:
        print("No hay números mayores o iguales a {} en la lista.".format(valor))
# Out:
# Cada 3.24 posiciones hay un número mayor o igual a 3.
# Cada 5.40 posiciones hay un número mayor o igual a 5.
# Cada 13.50 posiciones hay un número mayor o igual a 10.
# Cada 23.14 posiciones hay un número mayor o igual a 20.
# Cada 54.00 posiciones hay un número mayor o igual a 30.
